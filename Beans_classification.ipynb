# %%
import tensorflow as tf
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt
import numpy as np

# %%
def resize_and_rescale(image, label):
  image = tf.cast(image, tf.float32)
  image = tf.image.resize(image, [150, 150])
  image = (image / 255.0)
  return image, label

# %%
def prepreprocess(image, label):
  resized_image = tf.image.resize(image, [150,150])
  resized_image /= 255.0
  return resized_image, label

# %%
def f(image, label):
  seed = rng.make_seeds(2)[0]
  image, label = augment((image, label), seed)
  return image, label

# %%
def augment(image_label, seed):
  image, label = image_label
  image, label = prepreprocess(image, label)
  image = tf.image.resize_with_crop_or_pad(image, 150 + 6, 150 + 6)
  # Make a new seed.
  new_seed = tf.random.experimental.stateless_split(seed, num=1)[0, :]
  # Random crop back to the original size.
  image = tf.image.stateless_random_crop(
      image, size=[150, 150, 3], seed=seed)
  
#   #Random contrast
#   image = tf.image.stateless_random_contrast(
#       image, lower=0.1, upper=0.9, seed=seed)
  
  #Random flip
  image = tf.image.stateless_random_flip_left_right(
    image, seed = seed
)

  # Random brightness.
  image = tf.image.stateless_random_brightness(
      image, max_delta=0.5, seed=new_seed)
  image = tf.clip_by_value(image, 0, 1)
  return image, label

# %%
def preprocess():
    # Loads and splits the data into training and validation splits using tfds.
    (ds_train, ds_validation, ds_test), ds_info = tfds.load('beans', split = ['train', 'validation', 'test'], as_supervised = True, with_info = True)

    ds_train = ds_train.map(f).cache().shuffle(
        ds_info.splits['train'].num_examples).batch(BATCH_SIZE).prefetch(
        tf.data.experimental.AUTOTUNE)

    ds_validation = ds_validation.map(prepreprocess).batch(BATCH_SIZE).cache().prefetch(tf.data.experimental.AUTOTUNE)

    ds_test = ds_test.map(prepreprocess).batch(BATCH_SIZE).cache().prefetch(tf.data.experimental.AUTOTUNE)

    return ds_train, ds_validation, ds_test

# %%
def create_model(train_set, validation_set, test_set):
  
  model =  tf.keras.Sequential([
        tf.keras.layers.Conv2D(32, 3, activation = 'relu', input_shape = [150,150,3]),
        tf.keras.layers.MaxPool2D(2),
        tf.keras.layers.Conv2D(64, 3, activation = 'relu'),
        tf.keras.layers.MaxPool2D(2),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Conv2D(128, 3, activation = 'relu'),
        tf.keras.layers.MaxPool2D(2),
        tf.keras.layers.Conv2D(256, 3, activation = 'relu'),
        tf.keras.layers.MaxPool2D(2),
        tf.keras.layers.Dropout(0.7),       

        tf.keras.layers.Flatten(),
        tf.keras.layers.Dense(128,activation = 'relu'),
        tf.keras.layers.Dropout(0.7),

        tf.keras.layers.Dense(3, activation = 'softmax')

    ])
  
  model.compile(loss = tf.keras.losses.SparseCategoricalCrossentropy(), optimizer = tf.keras.optimizers.Adam(), metrics = ['accuracy'])

  # callback = tf.keras.callbacks.EarlyStopping(monitor = 'val_accuracy', patience = 4)
  # lr_callback = tf.keras.callbacks.LearningRateScheduler(lambda epochs: 1e-4 * 10 ** (epochs / 20))

  model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath=checkpoint_filepath,
    save_weights_only=True,
    monitor='val_accuracy',
    mode='max',
    save_best_only=True)
  

  model.fit(train_set, epochs = 100, validation_data = validation_set, callbacks = [model_checkpoint_callback])

  # plt.semilogx(history.history["lr"], history.history["val_accuracy"])
  # plt.axis([1e-4, 10, 0, 10])
  # plt.ylim([0,1])

  return model, test_set

# %%
def beans_classifier():
  train_set, validation_set, test_set = preprocess()  
  return create_model(train_set, validation_set, test_set)

# %%
if __name__ == '__main__':
  rng = tf.random.Generator.from_seed(123, alg='philox')
  BATCH_SIZE = 64
  checkpoint_filepath = '/tmp/checkpoint'

  model, ds_test = beans_classifier()

  model.load_weights(checkpoint_filepath)
  loss, acc = model.evaluate(ds_test)

  print("Loss on the test set is :", loss)
  print("Accuracy on the test set is :", acc)
# Out:
# Epoch 1/100
# 17/17 [==============================] - 4s 86ms/step - loss: 1.1834 - accuracy: 0.3240 - val_loss: 1.0977 - val_accuracy: 0.4737
# Epoch 2/100
# 17/17 [==============================] - 1s 55ms/step - loss: 1.0970 - accuracy: 0.3588 - val_loss: 1.0940 - val_accuracy: 0.4135
# Epoch 3/100
# 17/17 [==============================] - 1s 59ms/step - loss: 1.0975 - accuracy: 0.3723 - val_loss: 1.0856 - val_accuracy: 0.5414
# Epoch 4/100
# 17/17 [==============================] - 1s 55ms/step - loss: 1.0847 - accuracy: 0.3888 - val_loss: 1.0799 - val_accuracy: 0.3308
# Epoch 5/100
# 17/17 [==============================] - 1s 60ms/step - loss: 1.0477 - accuracy: 0.4603 - val_loss: 0.9497 - val_accuracy: 0.6541
# Epoch 6/100
# 17/17 [==============================] - 1s 68ms/step - loss: 0.9850 - accuracy: 0.5358 - val_loss: 0.8900 - val_accuracy: 0.6917
# Epoch 7/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.9809 - accuracy: 0.5213 - val_loss: 0.9255 - val_accuracy: 0.6015
# Epoch 8/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.8911 - accuracy: 0.6044 - val_loss: 0.8142 - val_accuracy: 0.6767
# Epoch 9/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.8847 - accuracy: 0.6035 - val_loss: 0.7966 - val_accuracy: 0.6842
# Epoch 10/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.8317 - accuracy: 0.6509 - val_loss: 0.7134 - val_accuracy: 0.7218
# Epoch 11/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.7908 - accuracy: 0.6557 - val_loss: 0.7260 - val_accuracy: 0.7143
# Epoch 12/100
# 17/17 [==============================] - 1s 59ms/step - loss: 0.8100 - accuracy: 0.6460 - val_loss: 0.7162 - val_accuracy: 0.7368
# Epoch 13/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.7397 - accuracy: 0.6712 - val_loss: 0.6662 - val_accuracy: 0.7594
# Epoch 14/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.7567 - accuracy: 0.6576 - val_loss: 0.6887 - val_accuracy: 0.6992
# Epoch 15/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.7657 - accuracy: 0.6547 - val_loss: 0.6596 - val_accuracy: 0.7444
# Epoch 16/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.7325 - accuracy: 0.6973 - val_loss: 0.6381 - val_accuracy: 0.7444
# Epoch 17/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.7363 - accuracy: 0.6838 - val_loss: 0.6770 - val_accuracy: 0.6767
# Epoch 18/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6885 - accuracy: 0.6847 - val_loss: 0.6204 - val_accuracy: 0.7293
# Epoch 19/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.7424 - accuracy: 0.6731 - val_loss: 0.6419 - val_accuracy: 0.7594
# Epoch 20/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6660 - accuracy: 0.7021 - val_loss: 0.5584 - val_accuracy: 0.7594
# Epoch 21/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6904 - accuracy: 0.7060 - val_loss: 0.6620 - val_accuracy: 0.6767
# Epoch 22/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6482 - accuracy: 0.6983 - val_loss: 0.6078 - val_accuracy: 0.7444
# Epoch 23/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6700 - accuracy: 0.7147 - val_loss: 0.6659 - val_accuracy: 0.7143
# Epoch 24/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6679 - accuracy: 0.7360 - val_loss: 0.5549 - val_accuracy: 0.7519
# Epoch 25/100
# 17/17 [==============================] - 1s 59ms/step - loss: 0.6482 - accuracy: 0.7166 - val_loss: 0.5543 - val_accuracy: 0.7820
# Epoch 26/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6087 - accuracy: 0.7350 - val_loss: 0.6121 - val_accuracy: 0.7594
# Epoch 27/100
# 17/17 [==============================] - 1s 66ms/step - loss: 0.6216 - accuracy: 0.7427 - val_loss: 0.5165 - val_accuracy: 0.7895
# Epoch 28/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.5994 - accuracy: 0.7418 - val_loss: 0.6557 - val_accuracy: 0.7744
# Epoch 29/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.6101 - accuracy: 0.7427 - val_loss: 0.5826 - val_accuracy: 0.7970
# Epoch 30/100
# 17/17 [==============================] - 1s 65ms/step - loss: 0.5389 - accuracy: 0.7611 - val_loss: 0.4715 - val_accuracy: 0.8571
# Epoch 31/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.5182 - accuracy: 0.7882 - val_loss: 0.5366 - val_accuracy: 0.8045
# Epoch 32/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.6033 - accuracy: 0.7485 - val_loss: 0.4813 - val_accuracy: 0.8346
# Epoch 33/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.5159 - accuracy: 0.7863 - val_loss: 0.4991 - val_accuracy: 0.7895
# Epoch 34/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.5273 - accuracy: 0.7785 - val_loss: 0.4547 - val_accuracy: 0.7895
# Epoch 35/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.4809 - accuracy: 0.8008 - val_loss: 0.4068 - val_accuracy: 0.8722
# Epoch 36/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.4274 - accuracy: 0.8095 - val_loss: 0.3552 - val_accuracy: 0.8797
# Epoch 37/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.4510 - accuracy: 0.8085 - val_loss: 0.4176 - val_accuracy: 0.8195
# Epoch 38/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4141 - accuracy: 0.8308 - val_loss: 0.3738 - val_accuracy: 0.8346
# Epoch 39/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.4167 - accuracy: 0.8230 - val_loss: 0.4364 - val_accuracy: 0.8045
# Epoch 40/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.6114 - accuracy: 0.7563 - val_loss: 0.4139 - val_accuracy: 0.8496
# Epoch 41/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.4882 - accuracy: 0.8056 - val_loss: 0.3765 - val_accuracy: 0.8271
# Epoch 42/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.4813 - accuracy: 0.8027 - val_loss: 0.3892 - val_accuracy: 0.8496
# Epoch 43/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.3961 - accuracy: 0.8482 - val_loss: 0.4394 - val_accuracy: 0.8421
# Epoch 44/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.4047 - accuracy: 0.8337 - val_loss: 0.3225 - val_accuracy: 0.8872
# Epoch 45/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.3781 - accuracy: 0.8549 - val_loss: 0.3501 - val_accuracy: 0.8571
# Epoch 46/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.4210 - accuracy: 0.8317 - val_loss: 0.2897 - val_accuracy: 0.8722
# Epoch 47/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.3335 - accuracy: 0.8694 - val_loss: 0.3159 - val_accuracy: 0.8797
# Epoch 48/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.3639 - accuracy: 0.8501 - val_loss: 0.3774 - val_accuracy: 0.8271
# Epoch 49/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.3715 - accuracy: 0.8598 - val_loss: 0.3254 - val_accuracy: 0.8571
# Epoch 50/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.3753 - accuracy: 0.8433 - val_loss: 0.4907 - val_accuracy: 0.8346
# Epoch 51/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.3969 - accuracy: 0.8308 - val_loss: 0.3672 - val_accuracy: 0.8421
# Epoch 52/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.3950 - accuracy: 0.8346 - val_loss: 0.3484 - val_accuracy: 0.8421
# Epoch 53/100
# 17/17 [==============================] - 1s 55ms/step - loss: 0.3747 - accuracy: 0.8366 - val_loss: 0.2780 - val_accuracy: 0.8496
# Epoch 54/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.3184 - accuracy: 0.8733 - val_loss: 0.2934 - val_accuracy: 0.8947
# Epoch 55/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.2950 - accuracy: 0.8714 - val_loss: 0.2746 - val_accuracy: 0.9023
# Epoch 56/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2976 - accuracy: 0.8704 - val_loss: 0.2996 - val_accuracy: 0.8872
# Epoch 57/100
# 17/17 [==============================] - 1s 59ms/step - loss: 0.2812 - accuracy: 0.8956 - val_loss: 0.2364 - val_accuracy: 0.9173
# Epoch 58/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.3173 - accuracy: 0.8830 - val_loss: 0.2863 - val_accuracy: 0.9023
# Epoch 59/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.2887 - accuracy: 0.8791 - val_loss: 0.2380 - val_accuracy: 0.9023
# Epoch 60/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.2581 - accuracy: 0.8936 - val_loss: 0.3347 - val_accuracy: 0.8797
# Epoch 61/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.3043 - accuracy: 0.8849 - val_loss: 0.2696 - val_accuracy: 0.8947
# Epoch 62/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2838 - accuracy: 0.8926 - val_loss: 0.2993 - val_accuracy: 0.9023
# Epoch 63/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2569 - accuracy: 0.8994 - val_loss: 0.3326 - val_accuracy: 0.8797
# Epoch 64/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.3052 - accuracy: 0.8897 - val_loss: 0.2775 - val_accuracy: 0.8797
# Epoch 65/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2505 - accuracy: 0.9081 - val_loss: 0.2567 - val_accuracy: 0.8947
# Epoch 66/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2559 - accuracy: 0.8936 - val_loss: 0.2880 - val_accuracy: 0.9023
# Epoch 67/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2291 - accuracy: 0.9149 - val_loss: 0.3412 - val_accuracy: 0.8797
# Epoch 68/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.2134 - accuracy: 0.9110 - val_loss: 0.2652 - val_accuracy: 0.8872
# Epoch 69/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2299 - accuracy: 0.9110 - val_loss: 0.2953 - val_accuracy: 0.8872
# Epoch 70/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.2382 - accuracy: 0.9004 - val_loss: 0.3164 - val_accuracy: 0.8872
# Epoch 71/100
# 17/17 [==============================] - 1s 60ms/step - loss: 0.2279 - accuracy: 0.9004 - val_loss: 0.2690 - val_accuracy: 0.9023
# Epoch 72/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2411 - accuracy: 0.9101 - val_loss: 0.3334 - val_accuracy: 0.8722
# Epoch 73/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2126 - accuracy: 0.9188 - val_loss: 0.3088 - val_accuracy: 0.8947
# Epoch 74/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2263 - accuracy: 0.9217 - val_loss: 0.3395 - val_accuracy: 0.8947
# Epoch 75/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.2170 - accuracy: 0.9217 - val_loss: 0.2812 - val_accuracy: 0.9023
# Epoch 76/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2285 - accuracy: 0.9043 - val_loss: 0.3273 - val_accuracy: 0.9023
# Epoch 77/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.1763 - accuracy: 0.9304 - val_loss: 0.3098 - val_accuracy: 0.9023
# Epoch 78/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2214 - accuracy: 0.9159 - val_loss: 0.2193 - val_accuracy: 0.8947
# Epoch 79/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.1933 - accuracy: 0.9275 - val_loss: 0.3121 - val_accuracy: 0.9023
# Epoch 80/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.1713 - accuracy: 0.9342 - val_loss: 0.2625 - val_accuracy: 0.8872
# Epoch 81/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.1546 - accuracy: 0.9449 - val_loss: 0.3812 - val_accuracy: 0.9023
# Epoch 82/100
# 17/17 [==============================] - 1s 62ms/step - loss: 0.1570 - accuracy: 0.9449 - val_loss: 0.3015 - val_accuracy: 0.8872
# Epoch 83/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1764 - accuracy: 0.9284 - val_loss: 0.3106 - val_accuracy: 0.9098
# Epoch 84/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.1620 - accuracy: 0.9381 - val_loss: 0.1831 - val_accuracy: 0.9474
# Epoch 85/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1698 - accuracy: 0.9342 - val_loss: 0.3103 - val_accuracy: 0.9098
# Epoch 86/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1943 - accuracy: 0.9265 - val_loss: 0.2291 - val_accuracy: 0.9173
# Epoch 87/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.2043 - accuracy: 0.9207 - val_loss: 0.2150 - val_accuracy: 0.9323
# Epoch 88/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1525 - accuracy: 0.9449 - val_loss: 0.2012 - val_accuracy: 0.9173
# Epoch 89/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1383 - accuracy: 0.9449 - val_loss: 0.2205 - val_accuracy: 0.9173
# Epoch 90/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.1455 - accuracy: 0.9487 - val_loss: 0.2495 - val_accuracy: 0.9173
# Epoch 91/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.2594 - accuracy: 0.9014 - val_loss: 0.1974 - val_accuracy: 0.9173
# Epoch 92/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.2504 - accuracy: 0.8907 - val_loss: 0.2104 - val_accuracy: 0.9173
# Epoch 93/100
# 17/17 [==============================] - 1s 61ms/step - loss: 0.1905 - accuracy: 0.9284 - val_loss: 0.2352 - val_accuracy: 0.9173
# Epoch 94/100
# 17/17 [==============================] - 1s 58ms/step - loss: 0.1418 - accuracy: 0.9507 - val_loss: 0.2591 - val_accuracy: 0.9248
# Epoch 95/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1442 - accuracy: 0.9400 - val_loss: 0.2462 - val_accuracy: 0.9248
# Epoch 96/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.1561 - accuracy: 0.9400 - val_loss: 0.2037 - val_accuracy: 0.9323
# Epoch 97/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1149 - accuracy: 0.9555 - val_loss: 0.1830 - val_accuracy: 0.9248
# Epoch 98/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.1307 - accuracy: 0.9439 - val_loss: 0.2850 - val_accuracy: 0.9098
# Epoch 99/100
# 17/17 [==============================] - 1s 56ms/step - loss: 0.1470 - accuracy: 0.9352 - val_loss: 0.1937 - val_accuracy: 0.9398
# Epoch 100/100
# 17/17 [==============================] - 1s 57ms/step - loss: 0.1097 - accuracy: 0.9565 - val_loss: 0.2736 - val_accuracy: 0.9248
# 2/2 [==============================] - 0s 142ms/step - loss: 0.2899 - accuracy: 0.8984
# Loss on the test set is : 0.2899131178855896
# Accuracy on the test set is : 0.8984375
